# %% [markdown]
# #  Projet Machine Learning avec <a href="https://cran.r-project.org/"><img src="https://cran.r-project.org/Rlogo.svg" style="max-width: 40px; display: inline" alt="R"/></a>

# %% [markdown]
# ## 1. Analyse exploratoire des données

# %%
install.packages(c("GGally","plotly","corrplot","reshape2","FactoMineR","factoextra","glmnet","ggfortify","pROC","ROCR"), dependencies = TRUE)
# Out:
# installation des dépendances ‘ucminf’, ‘ordinal’, ‘AsioHeaders’, ‘pan’, ‘jomo’, ‘coda’, ‘pkgbuild’, ‘websocket’, ‘zip’, ‘curl’, ‘wk’, ‘mitml’, ‘miniUI’, ‘shinyjs’, ‘commonmark’, ‘xfun’, ‘gss’, ‘stabledist’, ‘gbutils’, ‘TTR’, ‘RSpectra’, ‘FNN’, ‘multicool’, ‘pracma’, ‘bitops’, ‘scales’, ‘patchwork’, ‘cards’, ‘pcaPP’, ‘som’, ‘pls’, ‘tweenr’, ‘polyclip’, ‘htmlTable’, ‘statnet.common’, ‘rJava’, ‘hunspell’, ‘brio’, ‘cli’, ‘desc’, ‘evaluate’, ‘jsonlite’, ‘pkgload’, ‘praise’, ‘processx’, ‘ps’, ‘R6’, ‘rlang’, ‘waldo’, ‘diffobj’, ‘checkmate’, ‘chromote’, ‘globals’, ‘httr2’, ‘pingr’, ‘classInt’, ‘s2’, ‘units’, ‘rex’, ‘mice’, ‘doParallel’, ‘FactoInvestigate’, ‘colourpicker’, ‘shinydashboard’, ‘shinyjqui’, ‘litedown’, ‘fBasics’, ‘timeDate’, ‘fastICA’, ‘cvar’, ‘fracdiff’, ‘urca’, ‘xmlparsedata’, ‘terra’, ‘sandwich’, ‘quadprog’, ‘quantmod’, ‘rARPACK’, ‘ks’, ‘gtools’, ‘caTools’, ‘ggplot2’, ‘ggstats’, ‘S7’, ‘airports’, ‘broom.helpers’, ‘chemometrics’, ‘geosphere’, ‘ggforce’, ‘Hmisc’, ‘intergraph’, ‘labelled’, ‘mapproj’, ‘maps’, ‘network’, ‘scagnostics’, ‘sna’, ‘spelling’, ‘testthat’, ‘vdiffr’, ‘hexbin’, ‘ggthemes’, ‘shinytest2’, ‘Cairo’, ‘webshot’, ‘listviewer’, ‘sf’, ‘plotlyGeoAssets’, ‘palmerpenguins’, ‘rversions’, ‘rsvg’, ‘ggridges’, ‘prettydoc’, ‘covr’, ‘missMDA’, ‘Factoshiny’, ‘markdown’, ‘lars’, ‘changepoint’, ‘fGarch’, ‘forecast’, ‘KFAS’, ‘lintr’, ‘mapdata’, ‘MSwM’, ‘raster’, ‘strucchange’, ‘timeSeries’, ‘tseries’, ‘vars’, ‘xts’, ‘lfda’, ‘logcondens’, ‘gplots’
# Les packages binaires téléchargés sont dans
# 	/var/folders/jy/g1kgbm0143z4bwq5hxn2qbs80000gn/T//Rtmpr5Cqef/downloaded_packages

# %%
install.packages("ggplot2", repos = "https://cloud.r-project.org/")
# Out:
# Les packages binaires téléchargés sont dans
# 	/var/folders/jy/g1kgbm0143z4bwq5hxn2qbs80000gn/T//Rtmpja9N4z/downloaded_packages

# %%
#Chargement des librairies nécessaires

library(ggplot2)
library(tidyverse)
library(gridExtra)
library(GGally)
library(plotly)
library(corrplot)
library(reshape2)
library(FactoMineR) 
library(factoextra)
library(glmnet) 
library(ggfortify)
library(pROC)
library(ROCR)
# Out:
# Warning message:
# “le package ‘ggplot2’ a été compilé avec la version R 4.4.3”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.4     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attachement du package : ‘gridExtra’
#
#
# L'objet suivant est masqué depuis ‘package:dplyr’:
#
#     combine
#
#
# Warning message:
# “le package ‘plotly’ a été compilé avec la version R 4.4.3”
#
# Attachement du package : ‘plotly’
#
#
# L'objet suivant est masqué depuis ‘package:ggplot2’:
#
#     last_plot
#
#
# L'objet suivant est masqué depuis ‘package:stats’:
#
#     filter
#
#
# L'objet suivant est masqué depuis ‘package:graphics’:
#
#     layout
#
#
# corrplot 0.95 loaded
#
#
# Attachement du package : ‘reshape2’
#
#
# L'objet suivant est masqué depuis ‘package:tidyr’:
#
#     smiths
#
#
# Warning message:
# “le package ‘FactoMineR’ a été compilé avec la version R 4.4.3”
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# Le chargement a nécessité le package : Matrix
#
#
# Attachement du package : ‘Matrix’
#
#
# Les objets suivants sont masqués depuis ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
# Loaded glmnet 4.1-10
#
# Type 'citation("pROC")' for a citation.
#
#
# Attachement du package : ‘pROC’
#
#
# Les objets suivants sont masqués depuis ‘package:stats’:
#
#     cov, smooth, var
#
#
# Warning message:
# “le package ‘ROCR’ a été compilé avec la version R 4.4.3”

# %% [markdown]
# # Lecture des données

# %%
# Lecture des données
path <- ""
health <- read.csv(paste(path, "healthcare_synthetic_data.csv", sep = ""),
                    sep = ",", header = TRUE)
# Premières lignes du jeu de données
head(health)
# Vérification du contenu
summary(health)
# Out:
#   Patient_ID Age Gender Height_cm Weight_kg BMI  Systolic_BP Diastolic_BP
# 1 PID-00001  60  0      146.9     51.3      23.8 140          89
# 2 PID-00002  53  0      161.8     76.6      29.3 128          81
# 3 PID-00003  62  1      174.7     92.4      30.3 141         100
# 4 PID-00004  73  1      173.3     68.9      22.9 136          96
# 5 PID-00005  52  1      178.6     79.8      25.0 122          80
# 6 PID-00006  52  0      159.6     60.3      23.7 134          92
#   Cholesterol_Total Cholesterol_LDL Cholesterol_HDL Fasting_Blood_Sugar
# 1 217               151             52               83
# 2 203               119             38              116
# 3 173               124             45               90
# 4 193               117             45               81
# 5 236               153             41               79
# 6 225               155             48              103
#   Smoking_Status Alcohol_Consumption Physical_Activity_Level Family_History
# 1 0              1                   3                       0
# 2 0              0                   1                       0
# 3 0              0                   0                       0
# 4 0              0                   1                       0
# 5 0              1                   2                       0
# 6 0              0                   1                       1
#   Stress_Level Sleep_Hours Heart_Disease_Risk
# 1 1            8           0
# 2 7            9           0
# 3 1            7           1
# 4 2            7           1
# 5 2            6           0
# 6 4            8           0
#   Patient_ID             Age            Gender         Height_cm
#  Length:15000       Min.   :25.00   Min.   :0.0000   Min.   :138.5
#  Class :character   1st Qu.:46.00   1st Qu.:0.0000   1st Qu.:158.5
#  Mode  :character   Median :55.00   Median :0.0000   Median :164.7
#                     Mean   :54.54   Mean   :0.4919   Mean   :165.3
#                     3rd Qu.:63.00   3rd Qu.:1.0000   3rd Qu.:172.0
#                     Max.   :85.00   Max.   :1.0000   Max.   :198.1
#    Weight_kg           BMI         Systolic_BP     Diastolic_BP
#  Min.   : 33.70   Min.   :14.50   Min.   : 90.0   Min.   : 60.00
#  1st Qu.: 65.20   1st Qu.:24.50   1st Qu.:127.0   1st Qu.: 85.00
#  Median : 73.90   Median :27.20   Median :135.0   Median : 91.00
#  Mean   : 75.25   Mean   :27.45   Mean   :135.1   Mean   : 90.54
#  3rd Qu.: 83.90   3rd Qu.:30.00   3rd Qu.:143.0   3rd Qu.: 96.00
#  Max.   :150.10   Max.   :46.10   Max.   :182.0   Max.   :120.00
#  Cholesterol_Total Cholesterol_LDL Cholesterol_HDL Fasting_Blood_Sugar
#  Min.   :127.0     Min.   : 70.0   Min.   :20.00   Min.   : 60.00
#  1st Qu.:201.0     1st Qu.:128.0   1st Qu.:39.00   1st Qu.: 89.00
#  Median :216.0     Median :140.0   Median :43.00   Median : 99.00
#  Mean   :216.2     Mean   :140.4   Mean   :43.31   Mean   : 99.67
#  3rd Qu.:231.0     3rd Qu.:152.0   3rd Qu.:47.00   3rd Qu.:110.00
#  Max.   :303.0     Max.   :210.0   Max.   :68.00   Max.   :167.00
#  Smoking_Status   Alcohol_Consumption Physical_Activity_Level Family_History
#  Min.   :0.0000   Min.   :0.0000      Min.   :0.000           Min.   :0.0000
#  1st Qu.:0.0000   1st Qu.:0.0000      1st Qu.:1.000           1st Qu.:0.0000
#  Median :0.0000   Median :0.0000      Median :1.000           Median :0.0000
#  Mean   :0.3003   Mean   :0.6038      Mean   :1.298           Mean   :0.1495
#  3rd Qu.:1.0000   3rd Qu.:1.0000      3rd Qu.:2.000           3rd Qu.:0.0000
#  Max.   :1.0000   Max.   :2.0000      Max.   :3.000           Max.   :1.0000
#   Stress_Level     Sleep_Hours     Heart_Disease_Risk
#  Min.   : 1.000   Min.   : 4.000   Min.   :0.000
#  1st Qu.: 3.000   1st Qu.: 6.000   1st Qu.:0.000
#  Median : 5.500   Median : 7.000   Median :0.000
#  Mean   : 5.504   Mean   : 6.506   Mean   :0.436
#  3rd Qu.: 8.000   3rd Qu.: 7.000   3rd Qu.:1.000
#  Max.   :10.000   Max.   :10.000   Max.   :1.000

# %% [markdown]
# ## Changement du type des variables qualitatives en facteur

# %%
# Changement du type des variables qualitatives en facteur
health[, "Gender"] <- as.factor(health[, "Gender"])
health[, "Smoking_Status"] <- as.factor(health[, "Smoking_Status"])
health[, "Alcohol_Consumption"] <- as.factor(health[, "Alcohol_Consumption"])
health[, "Physical_Activity_Level"] <- as.factor(health[, "Physical_Activity_Level"])
health[, "Family_History"] <- as.factor(health[, "Family_History"])
health[, "Stress_Level"] <- as.factor(health[, "Stress_Level"])
health[, "Heart_Disease_Risk"] <- as.factor(health[, "Heart_Disease_Risk"])
health[, "Sleep_Hours"] <- as.factor(health[, "Sleep_Hours"])

# %%
summary(health)
# Out:
#   Patient_ID             Age        Gender     Height_cm       Weight_kg
#  Length:15000       Min.   :25.00   0:7622   Min.   :138.5   Min.   : 33.70
#  Class :character   1st Qu.:46.00   1:7378   1st Qu.:158.5   1st Qu.: 65.20
#  Mode  :character   Median :55.00            Median :164.7   Median : 73.90
#                     Mean   :54.54            Mean   :165.3   Mean   : 75.25
#                     3rd Qu.:63.00            3rd Qu.:172.0   3rd Qu.: 83.90
#                     Max.   :85.00            Max.   :198.1   Max.   :150.10
#
#       BMI         Systolic_BP     Diastolic_BP    Cholesterol_Total
#  Min.   :14.50   Min.   : 90.0   Min.   : 60.00   Min.   :127.0
#  1st Qu.:24.50   1st Qu.:127.0   1st Qu.: 85.00   1st Qu.:201.0
#  Median :27.20   Median :135.0   Median : 91.00   Median :216.0
#  Mean   :27.45   Mean   :135.1   Mean   : 90.54   Mean   :216.2
#  3rd Qu.:30.00   3rd Qu.:143.0   3rd Qu.: 96.00   3rd Qu.:231.0
#  Max.   :46.10   Max.   :182.0   Max.   :120.00   Max.   :303.0
#
#  Cholesterol_LDL Cholesterol_HDL Fasting_Blood_Sugar Smoking_Status
#  Min.   : 70.0   Min.   :20.00   Min.   : 60.00      0:10495
#  1st Qu.:128.0   1st Qu.:39.00   1st Qu.: 89.00      1: 4505
#  Median :140.0   Median :43.00   Median : 99.00
#  Mean   :140.4   Mean   :43.31   Mean   : 99.67
#  3rd Qu.:152.0   3rd Qu.:47.00   3rd Qu.:110.00
#  Max.   :210.0   Max.   :68.00   Max.   :167.00
#
#  Alcohol_Consumption Physical_Activity_Level Family_History  Stress_Level
#  0:7502              0:3020                  0:12757        10     :1530
#  1:5939              1:6009                  1: 2243        4      :1518
#  2:1559              2:4453                                 8      :1518
#                      3:1518                                 1      :1507
#                                                             6      :1505
#                                                             5      :1499
#                                                             (Other):5923
#  Sleep_Hours Heart_Disease_Risk
#  4 : 727     0:8460
#  5 :2303     1:6540
#  6 :4433
#  7 :4491
#  8 :2374
#  9 : 579
#  10:  93

# %% [markdown]
# # Exploration Elémentaire

# %% [markdown]
# ## Analyse unidimensionelle

# %% [markdown]
# ### Variables Quantitatives

# %%
g1<-ggplot(health,aes(x=Age))+
  geom_histogram(aes(y=after_stat(density)))+
  geom_density(alpha=.2, col="blue") 

g2<-ggplot(health,aes(x=Height_cm))+
  geom_histogram(aes(y=..density..))+
  geom_density(alpha=.2, col="blue") 

g3<-ggplot(health,aes(x=Weight_kg))+
  geom_histogram(aes(y=..density..))+
  geom_density(alpha=.2, col="blue") 

g4<-ggplot(health,aes(x=BMI))+
  geom_histogram(aes(y=..density..))+
  geom_density(alpha=.2, col="blue") 

g5<-ggplot(health,aes(x=Systolic_BP))+
  geom_histogram(aes(y=..density..))+
  geom_density(alpha=.2, col="blue") 

g6<-ggplot(health,aes(x=Diastolic_BP))+
  geom_histogram(aes(y=..density..))+
  geom_density(alpha=.2, col="blue") 

g7<-ggplot(health,aes(x=Cholesterol_Total))+
  geom_histogram(aes(y=..density..))+
  geom_density(alpha=.2, col="blue") 

g8<-ggplot(health,aes(x=Cholesterol_LDL))+
  geom_histogram(aes(y=..density..))+
  geom_density(alpha=.2, col="blue") 

g9<-ggplot(health,aes(x=Cholesterol_HDL))+
  geom_histogram(aes(y=..density..))+
  geom_density(alpha=.2, col="blue") 

g10<-ggplot(health,aes(x=Fasting_Blood_Sugar))+
  geom_histogram(aes(y=..density..))+
  geom_density(alpha=.2, col="blue") 


grid.arrange(g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,ncol=2,nrow=5)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title

# %% [markdown]
# #### Corrélation

# %%
ggpairs(health[, c(2,4:12)])
# Out:
# plot without title

# %%
corrplot(cor(health[, c(2,4:12)]),method="ellipse")
# Out:
# Plot with title “”

# %%
# Out:
# plot without title

# %% [markdown]
# ### Variables Qualitatives

# %%
e2<-ggplot(health, aes(x=Gender))+
           geom_bar()+
           ylab("")+
           ggtitle("Effectifs")

df2<- data.frame(group = levels(health$Gender),
                 value = as.vector(table(health$Gender))/nrow(health))
g2<-ggplot(df2, aes(x="",y=value, fill=group))+
           geom_bar(width=1,stat="identity")+
           coord_polar("y",start=0)+
           theme(legend.position="bottom")


grid.arrange(g2,e2,ncol=2)
# Out:
# plot without title

# %%
df3<- data.frame(group = levels(health$Smoking_Status),
                 value = as.vector(table(health$Smoking_Status))/nrow(health))
g3<-ggplot(df3, aes(x="",y=value, fill=group))+
           geom_bar(width=1,stat="identity")+
           coord_polar("y",start=0)+
           theme(legend.position="bottom")

e3<-ggplot(health, aes(x=Smoking_Status))+
           geom_bar()+
           ylab("")+
           ggtitle("Effectifs")

grid.arrange(g3,e3,ncol=2)
# Out:
# plot without title

# %%
df4<- data.frame(group = levels(health$Alcohol_Consumption),
                 value = as.vector(table(health$Alcohol_Consumption))/nrow(health))
g4<-ggplot(df4, aes(x="",y=value, fill=group))+
           geom_bar(width=1,stat="identity")+
           coord_polar("y",start=0)+
           theme(legend.position="bottom")

e4<-ggplot(health, aes(x=Alcohol_Consumption))+
           geom_bar()+
           ylab("")+
           ggtitle("Effectifs")

grid.arrange(g4,e4,ncol=2)
# Out:
# plot without title

# %%
df5<- data.frame(group = levels(health$Physical_Activity_Level),
                 value = as.vector(table(health$Physical_Activity_Level))/nrow(health))
g5<-ggplot(df5, aes(x="",y=value, fill=group))+
           geom_bar(width=1,stat="identity")+
           coord_polar("y",start=0)+
           theme(legend.position="bottom")

e5<-ggplot(health, aes(x=Physical_Activity_Level))+
           geom_bar()+
           ylab("")+
           ggtitle("Effectifs")

grid.arrange(g5,e5,ncol=2)
# Out:
# plot without title

# %%
df6<- data.frame(group = levels(health$Family_History),
                 value = as.vector(table(health$Family_History))/nrow(health))
g6<-ggplot(df6, aes(x="",y=value, fill=group))+
           geom_bar(width=1,stat="identity")+
           coord_polar("y",start=0)+
           theme(legend.position="bottom")

e6<-ggplot(health, aes(x=Family_History))+
           geom_bar()+
           ylab("")+
           ggtitle("Effectifs")

grid.arrange(g6,e6,ncol=2)
# Out:
# plot without title

# %%
df7<- data.frame(group = levels(health$Stress_Level),
                 value = as.vector(table(health$Stress_Level))/nrow(health))
g7<-ggplot(df7, aes(x="",y=value, fill=group))+
           geom_bar(width=1,stat="identity")+
           coord_polar("y",start=0)+
           theme(legend.position="bottom")

e7<-ggplot(health, aes(x=Stress_Level))+
           geom_bar()+
           ylab("")+
           ggtitle("Effectifs")

grid.arrange(g7,e7,ncol=2)
# Out:
# plot without title

# %%
df8<- data.frame(group = levels(health$Sleep_Hours),
                 value = as.vector(table(health$Sleep_Hours))/nrow(health))
g8<-ggplot(df8, aes(x="",y=value, fill=group))+
           geom_bar(width=1,stat="identity")+
           coord_polar("y",start=0)+
           theme(legend.position="bottom")

e8<-ggplot(health, aes(x=Sleep_Hours))+
           geom_bar()+
           ylab("")+
           ggtitle("Effectifs")

grid.arrange(g8,e8,ncol=2)
# Out:
# plot without title

# %%
df9<- data.frame(group = levels(health$Heart_Disease_Risk),
                 value = as.vector(table(health$Heart_Disease_Risk))/nrow(health))
g9<-ggplot(df9, aes(x="",y=value, fill=group))+
           geom_bar(width=1,stat="identity")+
           coord_polar("y",start=0)+
           theme(legend.position="bottom")

e9<-ggplot(health, aes(x=Heart_Disease_Risk))+
           geom_bar()+
           ylab("")+
           ggtitle("Effectifs")

grid.arrange(g9,e9,ncol=2)
# Out:
# plot without title
